# %% [markdown]
# ## Welcome to the basic neural network tutorial!
# The following notebook is designed to walk through the process of building and training your first neural network using the standalone MaCh3 python utilities!
#
# If you're writing scripts this is encapsulate in the objects in `MaCh3PythonUtils/config_reader` however this guide aims to break apart the process of writing the code for yourself!

# %% [markdown]
# The first step is to load in a MaCh3 MCMC fit as input file. This is done using the ChainHandler class!

# %%
# MaCh3Python Deps
from MaCh3PythonUtils.file_handling.chain_handler import ChainHandler
from MaCh3PythonUtils.machine_learning.ml_factory import MLFactory


# Other imports
from matplotlib import pyplot as plt
from pathlib import Path
import os
import pandas as pd
import shutil as sh 
import gdown
# Out:
# Using mps device

# %%
# Download file from google drive

file_url="https://drive.google.com/file/d/1iE6xFhn3BH_HnLUfQ7KFGy2wfeH52Rwf/view?usp=sharing"

# download the file
#input_file= Path("../models/demo_chain.root")
#input_file2 = Path("../models/demo_chain2.root")

# Get list of input files in folder (glob/sys/Path)
path = Path("../models/chain_files/")

path_l = [f"{path}/{x}" for x in os.listdir(path)]

# chain_list [for file in folder ChainHandler(input_file, chain_name, verbose=verbse)]
chain_list = []
for x in path_l:
    chain_handler = ChainHandler(x, 'posteriors', verbose='verbose')
    
    # Process all the files
    chain_handler.ignore_plots(["xsec_20", "xsec_19"])
    chain_handler.add_additional_plots(["xsec_0", "xsec_1", "xsec_2", "xsec_3", "xsec_4", "xsec_5", "xsec_6", "xsec_7", "xsec_8", "xsec_9", "xsec_10", "xsec_11", "xsec_12", "xsec_13",
                                    "xsec_14", "xsec_15", "xsec_16", "xsec_17", "xsec_18", "xsec_21", "xsec_22"])
    fitting_label = "LogL_systematic_xsec_cov"
    #We need to make sure the chain handler knows this exists, passing true means it is looking for some with that exact name
    #chain_handler.add_additional_plots(fitting_label, True)

    # Finally we can do some cuts to get rid of things like burn-in
    # chain_handler.add_new_cuts(["LogL<22.5", "step>10000", "delm2_23>0"])
    chain_handler.add_new_cuts(["step>0", "LogL_systematic_xsec_cov<12345"])

    # Last step is  convert the chain into a pandas dataframe
    y= chain_handler.convert_ttree_to_array()
    chain_list.append(chain_handler)

#print(f'Here is the list:{chain_list}')

main_chain = chain_list[0]
#print(main_chain.ttree_array)

main_chain.ttree_array['Chain ID']= 0 
print(main_chain.ttree_array.columns)

for id, chain in enumerate(chain_list[1:], start = 1):
    print(id, chain.ttree_array)
    #add ID to chain['id']
    chain.ttree_array['Chain ID'] = id
    main_chain.ttree_array = pd.concat([main_chain.ttree_array, chain.ttree_array])

#add the ttree_array to chain_list[0]



print(f'FINAL Framework: {main_chain.ttree_array}')



#print(main_chain)

#for chains in chain_list[1:]:
    #new_chain = pd.concat([main_chain.ttree_array,chains.ttree_array])

#print(f"final data frame: {new_chain}")




#   for chains_1, ...:
#        add chain_i.ttree_array to main_chain.ttree_array



#print(chain_handler.ttree_array.columns) #this shows the coloumns of the chain data- each of the coloumns are parameters that affect the probabiliity that neutrinos will change flavour?
#print(chain_handler.ttree_array) # this just shows the full array.
    
    
#[ChainHandler(x, chain_name, verbose=verbose) for x in path_l]

# Process all the files
# main_chain = chain_list[0]
# Add ID col to chain_list[0].ttree_array
# for id, chain in enumerate(ChainHandler[1:]):
#       add ID to chain['id']
#       add the ttree_array to chain_list[0]


#if not input_file2.exists():
    # download the file
    #input_file.parent.mkdir(parents=True, exist_ok=True)
    #gdown.download(file_url, str(input_file2), quiet=False, fuzzy=True)
# Out:
# Attempting to open ../models/chain_files/demo_chain3.root
# Succesfully opened ../models/chain_files/demo_chain3.root:posteriors
# Using 12 threads and requiring 0.032 Gb memory
# Using the following branches:
#   -> xsec_0
#   -> xsec_1
#   -> xsec_2
#   -> xsec_3
#   -> xsec_4
#   -> xsec_5
#   -> xsec_6
#   -> xsec_7
#   -> xsec_8
#   -> xsec_9
#   -> xsec_10
#   -> xsec_11
#   -> xsec_12
#   -> xsec_13
#   -> xsec_14
#   -> xsec_15
#   -> xsec_16
#   -> xsec_17
#   -> xsec_18
#   -> xsec_21
#   -> xsec_22
# Converted TTree to pandas dataframe with 99591 elements
# Attempting to open ../models/chain_files/demo_chain.root
# Succesfully opened ../models/chain_files/demo_chain.root:posteriors
# Using 12 threads and requiring 0.032 Gb memory
# Using the following branches:
#   -> xsec_0
#   -> xsec_1
#   -> xsec_2
#   -> xsec_3
#   -> xsec_4
#   -> xsec_5
#   -> xsec_6
#   -> xsec_7
#   -> xsec_8
#   -> xsec_9
#   -> xsec_10
#   -> xsec_11
#   -> xsec_12
#   -> xsec_13
#   -> xsec_14
#   -> xsec_15
#   -> xsec_16
#   -> xsec_17
#   -> xsec_18
#   -> xsec_21
#   -> xsec_22
# Converted TTree to pandas dataframe with 99591 elements
# Attempting to open ../models/chain_files/demo_chain2.root
# Succesfully opened ../models/chain_files/demo_chain2.root:posteriors
# Using 12 threads and requiring 0.032 Gb memory
# Using the following branches:
#   -> xsec_0
#   -> xsec_1
#   -> xsec_2
#   -> xsec_3
#   -> xsec_4
#   -> xsec_5
#   -> xsec_6
#   -> xsec_7
#   -> xsec_8
#   -> xsec_9
#   -> xsec_10
#   -> xsec_11
#   -> xsec_12
#   -> xsec_13
#   -> xsec_14
#   -> xsec_15
#   -> xsec_16
#   -> xsec_17
#   -> xsec_18
#   -> xsec_21
#   -> xsec_22
# Converted TTree to pandas dataframe with 99591 elements
# Index(['xsec_0', 'xsec_1', 'xsec_2', 'xsec_3', 'xsec_4', 'xsec_5', 'xsec_6',
#        'xsec_7', 'xsec_8', 'xsec_9', 'xsec_10', 'xsec_11', 'xsec_12',
#        'xsec_13', 'xsec_14', 'xsec_15', 'xsec_16', 'xsec_17', 'xsec_18',
#        'xsec_21', 'xsec_22', 'Chain ID'],
#       dtype='object')
# 1          xsec_0    xsec_1    xsec_2    xsec_3    xsec_4    xsec_5    xsec_6  \
# 0      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# 1      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# 2      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# 3      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# 4      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# ...         ...       ...       ...       ...       ...       ...       ...
# 99994  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
# 99995  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
# 99996  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
# 99997  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
# 99998  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
#
#          xsec_7    xsec_8    xsec_9  ...   xsec_11   xsec_12   xsec_13  \
# 0      1.209131  1.083522  0.866298  ...  0.994566  1.027940  1.202054
# 1      1.209131  1.083522  0.866298  ...  0.994566  1.027940  1.202054
# 2      1.209131  1.083522  0.866298  ...  0.994566  1.027940  1.202054
# 3      1.209131  1.083522  0.866298  ...  0.994566  1.027940  1.202054
# 4      1.209131  1.083522  0.866298  ...  0.994566  1.027940  1.202054
# ...         ...       ...       ...  ...       ...       ...       ...
# 99994  0.911710  1.200054  1.002491  ...  0.990030  1.012565  1.331104
# 99995  0.911710  1.200054  1.002491  ...  0.990030  1.012565  1.331104
# 99996  0.911710  1.200054  1.002491  ...  0.990030  1.012565  1.331104
# 99997  0.911710  1.200054  1.002491  ...  0.990030  1.012565  1.331104
# 99998  0.911710  1.200054  1.002491  ...  0.990030  1.012565  1.331104
#
#         xsec_14   xsec_15   xsec_16   xsec_17   xsec_18   xsec_21   xsec_22
# 0      1.116282  0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196
# 1      1.116282  0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196
# 2      1.116282  0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196
# 3      1.116282  0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196
# 4      1.116282  0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196
# ...         ...       ...       ...       ...       ...       ...       ...
# 99994  0.705606  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010
# 99995  0.705606  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010
# 99996  0.705606  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010
# 99997  0.705606  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010
# 99998  0.705606  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010
#
# [99591 rows x 21 columns]
# 2          xsec_0    xsec_1    xsec_2    xsec_3    xsec_4    xsec_5    xsec_6  \
# 0      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# 1      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# 2      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# 3      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# 4      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# ...         ...       ...       ...       ...       ...       ...       ...
# 99994  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
# 99995  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
# 99996  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
# 99997  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
# 99998  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
#
#          xsec_7    xsec_8    xsec_9  ...   xsec_11   xsec_12   xsec_13  \
# 0      1.209131  1.083522  0.866298  ...  0.994566  1.027940  1.202054
# 1      1.209131  1.083522  0.866298  ...  0.994566  1.027940  1.202054
# 2      1.209131  1.083522  0.866298  ...  0.994566  1.027940  1.202054
# 3      1.209131  1.083522  0.866298  ...  0.994566  1.027940  1.202054
# 4      1.209131  1.083522  0.866298  ...  0.994566  1.027940  1.202054
# ...         ...       ...       ...  ...       ...       ...       ...
# 99994  0.911710  1.200054  1.002491  ...  0.990030  1.012565  1.331104
# 99995  0.911710  1.200054  1.002491  ...  0.990030  1.012565  1.331104
# 99996  0.911710  1.200054  1.002491  ...  0.990030  1.012565  1.331104
# 99997  0.911710  1.200054  1.002491  ...  0.990030  1.012565  1.331104
# 99998  0.911710  1.200054  1.002491  ...  0.990030  1.012565  1.331104
#
#         xsec_14   xsec_15   xsec_16   xsec_17   xsec_18   xsec_21   xsec_22
# 0      1.116282  0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196
# 1      1.116282  0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196
# 2      1.116282  0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196
# 3      1.116282  0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196
# 4      1.116282  0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196
# ...         ...       ...       ...       ...       ...       ...       ...
# 99994  0.705606  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010
# 99995  0.705606  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010
# 99996  0.705606  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010
# 99997  0.705606  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010
# 99998  0.705606  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010
#
# [99591 rows x 21 columns]
# FINAL Framework:          xsec_0    xsec_1    xsec_2    xsec_3    xsec_4    xsec_5    xsec_6  \
# 0      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# 1      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# 2      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# 3      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# 4      1.193532  1.011216  1.250193  1.067571  0.793567  1.070356  0.951044
# ...         ...       ...       ...       ...       ...       ...       ...
# 99994  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
# 99995  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
# 99996  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
# 99997  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
# 99998  1.159800  1.084834  1.117669  0.915306  1.017123  0.966494  1.053807
#
#          xsec_7    xsec_8    xsec_9  ...   xsec_12   xsec_13   xsec_14  \
# 0      1.209131  1.083522  0.866298  ...  1.027940  1.202054  1.116282
# 1      1.209131  1.083522  0.866298  ...  1.027940  1.202054  1.116282
# 2      1.209131  1.083522  0.866298  ...  1.027940  1.202054  1.116282
# 3      1.209131  1.083522  0.866298  ...  1.027940  1.202054  1.116282
# 4      1.209131  1.083522  0.866298  ...  1.027940  1.202054  1.116282
# ...         ...       ...       ...  ...       ...       ...       ...
# 99994  0.911710  1.200054  1.002491  ...  1.012565  1.331104  0.705606
# 99995  0.911710  1.200054  1.002491  ...  1.012565  1.331104  0.705606
# 99996  0.911710  1.200054  1.002491  ...  1.012565  1.331104  0.705606
# 99997  0.911710  1.200054  1.002491  ...  1.012565  1.331104  0.705606
# 99998  0.911710  1.200054  1.002491  ...  1.012565  1.331104  0.705606
#
#         xsec_15   xsec_16   xsec_17   xsec_18   xsec_21   xsec_22  Chain ID
# 0      0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196         0
# 1      0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196         0
# 2      0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196         0
# 3      0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196         0
# 4      0.765340  1.061629  0.976704  0.605495  0.000236 -0.000196         0
# ...         ...       ...       ...       ...       ...       ...       ...
# 99994  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010         2
# 99995  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010         2
# 99996  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010         2
# 99997  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010         2
# 99998  0.989677  1.059074  1.052415  0.872381 -0.000536  0.000010         2
#
# [298773 rows x 22 columns]

# %%
# Load in a file, for the purposes of this example we'll use a
# input_file = Path("../../../../T2K/AdaptiveTune/SummerProj/Adapt/NOvA/LongFit/Cut/mcmc_Adapt_NOvA_all_on.root")

# Set up file properties
chain_name = 'posteriors'
verbose=False

chain_handler = ChainHandler(str(input_file), chain_name, verbose=verbose)
chain_handler2= ChainHandler((input_file2), chain_name, verbose=verbose)
# Out:
# Attempting to open ../models/demo_chain.root
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Desktop/MaCh3-PythonUtils/src/MaCh3PythonUtils/file_handling/chain_handler.py:39, in ChainHandler.__init__(self, file_name, ttree_name, verbose)
#      38 try:
# ---> 39     self._posterior_ttree = ur.open(f"{file_name}:{ttree_name}")
#      41 except FileNotFoundError:
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/uproot/reading.py:142, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     136     raise ValueError(
#     137         "'path' must be a string, pathlib.Path, an object with 'read' and "
#     138         "'seek' methods, or a length-1 dict of {file_path: object_path}, "
#     139         f"not {path!r}"
#     140     )
# --> 142 file = ReadOnlyFile(
#     143     file_path,
#     144     object_cache=object_cache,
#     145     array_cache=array_cache,
#     146     custom_classes=custom_classes,
#     147     decompression_executor=decompression_executor,
#     148     interpretation_executor=interpretation_executor,
#     149     **options,
#     150 )
#     152 if object_path is None:
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/uproot/reading.py:573, in ReadOnlyFile.__init__(self, file_path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     566     raise ValueError(
#     567         "begin_chunk_size={} is not enough to read the TFile header ({})".format(
#     568             self._options["begin_chunk_size"],
#     569             _file_header_fields_big.size,
#     570         )
#     571     )
# --> 573 self._begin_chunk = self._source.chunk(
#     574     0, self._options["begin_chunk_size"]
#     575 ).detach_memmap()
#     577 self.hook_before_interpret()
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/uproot/source/fsspec.py:95, in FSSpecSource.chunk(self, start, stop)
#      94 self._num_requested_bytes += stop - start
# ---> 95 data = self._fs.cat_file(self._file_path, start=start, end=stop)
#      96 future = uproot.source.futures.TrivialFuture(data)
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/fsspec/spec.py:797, in AbstractFileSystem.cat_file(self, path, start, end, **kwargs)
#     796 # explicitly set buffering off?
# --> 797 with self.open(path, "rb", **kwargs) as f:
#     798     if start is not None:
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/fsspec/spec.py:1338, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1337 ac = kwargs.pop("autocommit", not self._intrans)
# -> 1338 f = self._open(
#    1339     path,
#    1340     mode=mode,
#    1341     block_size=block_size,
#    1342     autocommit=ac,
#    1343     cache_options=cache_options,
#    1344     **kwargs,
#    1345 )
#    1346 if compression is not None:
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/fsspec/implementations/local.py:206, in LocalFileSystem._open(self, path, mode, block_size, **kwargs)
#     205     self.makedirs(self._parent(path), exist_ok=True)
# --> 206 return LocalFileOpener(path, mode, fs=self, **kwargs)
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/fsspec/implementations/local.py:383, in LocalFileOpener.__init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     382 self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 383 self._open()
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/fsspec/implementations/local.py:388, in LocalFileOpener._open(self)
#     387 if self.autocommit or "w" not in self.mode:
# --> 388     self.f = open(self.path, mode=self.mode)
#     389     if self.compression:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/edwin/Desktop/MaCh3-PythonUtils/notebooks/../models/demo_chain.root'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[28], line 8
#       5 chain_name = 'posteriors'
#       6 verbose=False
# ----> 8 chain_handler = ChainHandler(str(input_file), chain_name, verbose=verbose)
#       9 chain_handler2= ChainHandler((input_file2), chain_name, verbose=verbose)
#
# File ~/Desktop/MaCh3-PythonUtils/src/MaCh3PythonUtils/file_handling/chain_handler.py:42, in ChainHandler.__init__(self, file_name, ttree_name, verbose)
#      39     self._posterior_ttree = ur.open(f"{file_name}:{ttree_name}")
#      41 except FileNotFoundError:
# ---> 42     raise IOError(f"The file '{file_name}' does not exist or does not contain '{ttree_name}")
#      44 print(f"Succesfully opened {file_name}:{ttree_name}")
#      45 warnings.filterwarnings("ignore", category=DeprecationWarning) #Some imports are a little older
#
# OSError: The file '../models/demo_chain.root' does not exist or does not contain 'posteriors

# %% [markdown]
# - ChainHandler is a class that loads in some generic TTree objects and export to numpy array/pandas dataframe (conversion)
# - The arguements that need to be inputted can be found in the ChainHandler.py file

# %% [markdown]
# Okay, now we've loaded in a file we need to do a bit of processing. This means we need to select the variables we care about and apply parameter cuts

# %%
# Firstly we set things we want to ignore, these are parameters we really don't care about/want to learn!
# chain_handler.ignore_plots(["LogL_systematic_xsec_cov", "Log", "LogL_systematic_osc_cov"])
chain_name = 'posteriors'
verbose=False

chain_handler = ChainHandler(input, chain_name, verbose=verbose)



chain_handler.ignore_plots(["xsec_20", "xsec_19"])
chain_handler.add_additional_plots(["xsec_0", "xsec_1", "xsec_2", "xsec_3", "xsec_4", "xsec_5", "xsec_6", "xsec_7", "xsec_8", "xsec_9", "xsec_10", "xsec_11", "xsec_12", "xsec_13",
                                    "xsec_14", "xsec_15", "xsec_16", "xsec_17", "xsec_18", "xsec_21", "xsec_22"])

# Now we add parameters we care about. Note this only need to be a substring of the full name
# chain_handler.add_additional_plots(["sin2th", "delm2", "delta", "xsec"])

# The fitting label is special, it's the thing we want to train our network to predict
fitting_label = "LogL_systematic_xsec_cov"
# We need to make sure the chain handler knows this exists, passing true means it is looking for some with that exact name
chain_handler.add_additional_plots(fitting_label, True)

# Finally we can do some cuts to get rid of things like burn-in
# chain_handler.add_new_cuts(["LogL<22.5", "step>10000", "delm2_23>0"])
chain_handler.add_new_cuts(["step>0", "LogL_systematic_xsec_cov<12345"])

# Last step is convert the chain into a pandas dataframe
chain_handler.convert_ttree_to_array()



print(chain_handler.ttree_array.columns) #this shows the coloumns of the chain data- each of the coloumns are parameters that affect the probabiliity that neutrinos will change flavour?
#print(chain_handler.ttree_array) # this just shows the full array.

#chain ID: 0
#df = chain_handler.ttree_array
#df['Chain ID']=0
#print(chain_handler.ttree_array.columns)
#print(1.ttree_array)

#chain ID: 1
#df2 = pd.DataFrame(chain_handler2.ttree_array)
#df2['Chain ID']=1
#print(df2.columns)
# Out:
# Attempting to open <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x106dcb690>>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Desktop/MaCh3-PythonUtils/src/MaCh3PythonUtils/file_handling/chain_handler.py:39, in ChainHandler.__init__(self, file_name, ttree_name, verbose)
#      38 try:
# ---> 39     self._posterior_ttree = ur.open(f"{file_name}:{ttree_name}")
#      41 except FileNotFoundError:
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/uproot/reading.py:142, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     136     raise ValueError(
#     137         "'path' must be a string, pathlib.Path, an object with 'read' and "
#     138         "'seek' methods, or a length-1 dict of {file_path: object_path}, "
#     139         f"not {path!r}"
#     140     )
# --> 142 file = ReadOnlyFile(
#     143     file_path,
#     144     object_cache=object_cache,
#     145     array_cache=array_cache,
#     146     custom_classes=custom_classes,
#     147     decompression_executor=decompression_executor,
#     148     interpretation_executor=interpretation_executor,
#     149     **options,
#     150 )
#     152 if object_path is None:
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/uproot/reading.py:573, in ReadOnlyFile.__init__(self, file_path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     566     raise ValueError(
#     567         "begin_chunk_size={} is not enough to read the TFile header ({})".format(
#     568             self._options["begin_chunk_size"],
#     569             _file_header_fields_big.size,
#     570         )
#     571     )
# --> 573 self._begin_chunk = self._source.chunk(
#     574     0, self._options["begin_chunk_size"]
#     575 ).detach_memmap()
#     577 self.hook_before_interpret()
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/uproot/source/fsspec.py:95, in FSSpecSource.chunk(self, start, stop)
#      94 self._num_requested_bytes += stop - start
# ---> 95 data = self._fs.cat_file(self._file_path, start=start, end=stop)
#      96 future = uproot.source.futures.TrivialFuture(data)
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/fsspec/spec.py:797, in AbstractFileSystem.cat_file(self, path, start, end, **kwargs)
#     796 # explicitly set buffering off?
# --> 797 with self.open(path, "rb", **kwargs) as f:
#     798     if start is not None:
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/fsspec/spec.py:1338, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1337 ac = kwargs.pop("autocommit", not self._intrans)
# -> 1338 f = self._open(
#    1339     path,
#    1340     mode=mode,
#    1341     block_size=block_size,
#    1342     autocommit=ac,
#    1343     cache_options=cache_options,
#    1344     **kwargs,
#    1345 )
#    1346 if compression is not None:
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/fsspec/implementations/local.py:206, in LocalFileSystem._open(self, path, mode, block_size, **kwargs)
#     205     self.makedirs(self._parent(path), exist_ok=True)
# --> 206 return LocalFileOpener(path, mode, fs=self, **kwargs)
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/fsspec/implementations/local.py:383, in LocalFileOpener.__init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     382 self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 383 self._open()
#
# File ~/Desktop/MaCh3-PythonUtils/.venv/lib/python3.11/site-packages/fsspec/implementations/local.py:388, in LocalFileOpener._open(self)
#     387 if self.autocommit or "w" not in self.mode:
# --> 388     self.f = open(self.path, mode=self.mode)
#     389     if self.compression:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/edwin/Desktop/MaCh3-PythonUtils/notebooks/<bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x106dcb690>>:posteriors'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 6
#       3 chain_name = 'posteriors'
#       4 verbose=False
# ----> 6 chain_handler = ChainHandler(input, chain_name, verbose=verbose)
#       7 #chain_handler2= ChainHandler(str(input_file2), chain_name, verbose=verbose)
#      10 chain_handler.ignore_plots(["xsec_20", "xsec_19"])
#
# File ~/Desktop/MaCh3-PythonUtils/src/MaCh3PythonUtils/file_handling/chain_handler.py:42, in ChainHandler.__init__(self, file_name, ttree_name, verbose)
#      39     self._posterior_ttree = ur.open(f"{file_name}:{ttree_name}")
#      41 except FileNotFoundError:
# ---> 42     raise IOError(f"The file '{file_name}' does not exist or does not contain '{ttree_name}")
#      44 print(f"Succesfully opened {file_name}:{ttree_name}")
#      45 warnings.filterwarnings("ignore", category=DeprecationWarning) #Some imports are a little older
#
# OSError: The file '<bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x106dcb690>>' does not exist or does not contain 'posteriors

# %% [markdown]
# - Essentially the plot below is for a single parameter of the MCMC and how they vary from chain to chain (no training is done here)

# %% [markdown]
# Let's quickly use the chain handler to make a plot of the trace and posterior!

# %%
from MaCh3PythonUtils.file_handling.chain_diagnostics import ChainDiagnostics
plotter=ChainDiagnostics(chain_handler)

plotter("xsec_10")
plt.show()

# %% [markdown]
# - This just plots one paramater and the section is purely for a plotting demo

# %% [markdown]
# ## Machine learning
# Okay now we've done some very basic file manipulation, it's time for some machine learning!
# All algorithms use the same common `MLFactory` interface so let's go about configuring it!

# %%
# First step we need to initialise the factory

from pathlib import Path

model_output=Path("../models/my_model")
# Make sure the model output directory exists
model_output.parent.mkdir(parents=True, exist_ok=True)

# The factory produces ML models, we need to pass it the chain handler and the fitting label to get started
ml_factory = MLFactory(chain_handler, fitting_label, f"{model_output}.pdf")

# %% [markdown]
# - ML_Factory is essentailly a Class that allows me to use a chosen framework (i.e scikit-learn, PyTorch, etc..) and add kwargs from those frameworks on a single line.
# - If I ever wanted to see what function does that is inside the ML_factory, just go onto the file and it's there.

# %% [markdown]
# Now we need to define a model, for this demonstration we'll make a very simple neural network!

# %%
# We now want the actual neural network properties
# Usually you set this using a YAML file (see configs for some examples) but we'll do this manually for now
build_settings = {
}

# Settings used when the model is fitting
fit_settings = {
    'num_epochs': 8000,
    'learning_rate': 0.01,
    'debug': True,
}

# %% [markdown]
# - Ignore 'build_settings' - TensorFlow
# - 'fit_settings' is a dictionary that is an input (kwargs**) for ML_factory

# %%
# Now we can make the model
layers = []
layers.append({"linear": {"in_features": chain_handler.ndim-1, "out_features": 16}}) #input layer (starting nodes)
layers.append({"batch_norm": {'num_features': 16}}) #normalisation (wieghtings now will go from 0 to 1)
layers.append({"leaky_relu": {}}) #activation function
layers.append({"linear": {"in_features": 16, "out_features": 32}}) # "in_features: N " and "out_features: M" where N,M are integers that correspond to the number of nodes
layers.append({"leaky_relu": {}}) #activation function
layers.append({"linear": {"in_features": 32, "out_features": 8}})
layers.append({"leaky_relu": {}}) #activation function
layers.append({"linear": {"in_features": 8, "out_features": 1}})#layer of nodes: 64 inputs from previous layer, and 1 output


ml_model = ml_factory.make_interface('Torch', 'sequential', Layers=layers, FitSettings=fit_settings, BuildSettings=build_settings)
# def make_interface(self, interface_type: str, algorithm: str, **kwargs): (from ml_factory.py)



# Let's use 20% of the data for testing
ml_model.set_training_test_set(0.2)

# %% [markdown]
# - Generally, the order of creating a neural network is: input layer ----> normalisation ---> activation function then repeat at the output you want "out_features:1"
# - The output corresponds to the Loss function (which takes many forms but one of the standards is mod|Predicted - True| )
# - See how ml_factory is called and the interface is used as explained before: I have selected PyTorch as my framework, and added in the kwargs. One can see (from the comment underneath) that interface type is Torch and algorithm is sequential (in ml_factory.py Torch has only one alg but scikit has many). One can also see that the kwargs** are drawn in from a separate file ('torch_interface.py') which is basically a Class that CONTAINS the kwargs** - this is the essence of the factory where one can choose an alogorithm from a framework (Class) and also add in the kwargs necessary for that class in just one line.
# - One can see on the 'torch_interface.py' file that the kwargs start at line 21.

# %%
# Now we need to train our network
ml_model.train_model()
# Out:
# Training model:   0%|          | 0/8000 [00:00<?, ?epoch/s]

# %% [markdown]
# - if s

# %% [markdown]
# - The loss function can take many forms: a standard Loss function might look like L = |prediction - true|
# - When the model 'trains', it essentially tries to decrease the value of the Loss function.
# - However, there is a point in which the model can train too well (overfitting); this corresponds to the loss function being too small and it essentially means that the model learns the data too well that it cannot be used to predict values on new data. A diagram can be seen on the LaTeX document that I have access to.

# %%
# Now we need to test
ml_model.test_model()
# Out:
# Training Results!
# Mean Absolute Error : 180.71892698375632
# Line of best fit : y=3.590156485169192e-05x + -0.0064880922770358266
# Saving QQ to train_qq_plot.pdf
# mean: -180.71892698375632, std dev: 140.5586404121282
# =====
# Testing Results!
# Mean Absolute Error : 181.2088144523718
# Line of best fit : y=-1.6894124430839897e-05x + -0.00017687948846437915
# Saving QQ to .pdf
# mean: -181.2088144523718, std dev: 140.93736505340303
# =====

# %%
# Now we can save it
ml_model.print_model_summary()
# Out:
# Model Summary:
# Model: Sequential(
#   (0): Linear(in_features=22, out_features=16, bias=True)
#   (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): Linear(in_features=16, out_features=32, bias=True)
#   (4): LeakyReLU(negative_slope=0.01)
#   (5): Linear(in_features=32, out_features=8, bias=True)
#   (6): LeakyReLU(negative_slope=0.01)
#   (7): Linear(in_features=8, out_features=1, bias=True)
# )
# Device: mps
