# %% [markdown]
# ## Welcome to the basic neural network tutorial!
# The following notebook is designed to walk through the process of building and training your first neural network using the standalone MaCh3 python utilities!
#
# If you're writing scripts this is encapsulate in the objects in `MaCh3PythonUtils/config_reader` however this guide aims to break apart the process of writing the code for yourself!

# %% [markdown]
# The first step is to load in a MaCh3 MCMC fit as input file. This is done using the ChainHandler class!

# %%
# MaCh3Python Deps
from MaCh3PythonUtils.file_handling.chain_handler import ChainHandler
from MaCh3PythonUtils.machine_learning.ml_factory import MLFactory

import tensorflow as tf

# Other imports
from matplotlib import pyplot as plt
from pathlib import Path
import gdown
# Out:
# WARNING:tensorflow:From c:\Users\lucie\Documents\Summer25\MaCh3-PythonUtils\.conda\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\lucie\Documents\Summer25\MaCh3-PythonUtils\.conda\Lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From c:\Users\lucie\Documents\Summer25\MaCh3-PythonUtils\.conda\Lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.
# Using cpu device

# %%
# Download file from google drive

file_url="https://drive.google.com/file/d/1iE6xFhn3BH_HnLUfQ7KFGy2wfeH52Rwf/view?usp=sharing"

# download the file
input_file = Path("../models/demo_chain.root")

if not input_file.exists():
    # download the file
    input_file.parent.mkdir(parents=True, exist_ok=True)
    gdown.download(file_url, str(input_file), quiet=False, fuzzy=True)

# %%
# Load in a file, for the purposes of this example we'll use a
# input_file = Path("../../../../T2K/AdaptiveTune/SummerProj/Adapt/NOvA/LongFit/Cut/mcmc_Adapt_NOvA_all_on.root")

# Set up file properties
chain_name = 'posteriors'
verbose=False

chain_handler = ChainHandler(str(input_file), chain_name, verbose=verbose)
# Out:
# Attempting to open ..\models\demo_chain.root
# Succesfully opened ..\models\demo_chain.root:posteriors

# %% [markdown]
# Okay, now we've loaded in a file we need to do a bit of processing. This means we need to select the variables we care about and apply parameter cuts

# %%
# Firstly we set things we want to ignore, these are parameters we really don't care about/want to learn!
# chain_handler.ignore_plots(["LogL_systematic_xsec_cov", "Log", "LogL_systematic_osc_cov"])

chain_handler.ignore_plots(["xsec_20", "xsec_19"])
chain_handler.add_additional_plots(["xsec_0", "xsec_1", "xsec_2", "xsec_3", "xsec_4", "xsec_5", "xsec_6", "xsec_7", "xsec_8", "xsec_9", "xsec_10", "xsec_11", "xsec_12", "xsec_13",
                                    "xsec_14", "xsec_15", "xsec_16", "xsec_17", "xsec_18", "xsec_21", "xsec_22"])
# Now we add parameters we care about. Note this only need to be a substring of the full name
# chain_handler.add_additional_plots(["sin2th", "delm2", "delta", "xsec"])

# The fitting label is special, it's the thing we want to train our network to predict
fitting_label = "LogL_systematic_xsec_cov"
# We need to make sure the chain handler knows this exists, passing true means it is looking for some with that exact name
chain_handler.add_additional_plots(fitting_label, True)

# Finally we can do some cuts to get rid of things like burn-in
# chain_handler.add_new_cuts(["LogL<22.5", "step>10000", "delm2_23>0"])
chain_handler.add_new_cuts(["step>0", "LogL_systematic_xsec_cov<12345"])

# Last step is convert the chain into a pandas dataframe
chain_handler.convert_ttree_to_array()

# %% [markdown]
# Let's quickly use the chain handler to make a plot of the trace and posterior!

# %%
from MaCh3PythonUtils.file_handling.chain_diagnostics import ChainDiagnostics
plotter=ChainDiagnostics(chain_handler)

plotter("xsec_0")
plt.show()

# %% [markdown]
# ## Machine learning
# Okay now we've done some very basic file manipulation, it's time for some machine learning!
# All algorithms use the same common `MLFactory` interface so let's go about configuring it!

# %%
# First step we need to initialise the factory

from pathlib import Path


model_output=Path("../models/my_model")
# Make sure the model output directory exists
model_output.parent.mkdir(parents=True, exist_ok=True)

# The factory produces ML models, we need to pass it the chain handler and the fitting label to get started
ml_factory = MLFactory(chain_handler, fitting_label, f"{model_output}.pdf")

# %% [markdown]
# Now we need to define a model, for this demonstration we'll make a very simple neural network!

# %%
# Finally we need to set the layers

# In the YAML format this would be simple but here we'll use some helper functions
def dense_layer(n_neurons: int, activation: str, regularize: bool = True):
    '''This function sets the properties of a dense layer'''
    return {'dense': {
        'units': n_neurons,
        'activation': activation,
        'kernel_regularizer': regularize,
        'kernel_initializer': tf.keras.initializers.HeUniform(seed=42),
        'bias_initializer': 'zeros',
    }}
    
def batch_norm(momentum: float = 0.9):
    '''This function sets the properties of a batch norm layer'''
    return {'batchnorm': {
        'momentum': momentum
    }}
    
def dropout_layer(dropout_rate: float):
    '''This function sets the properties of a dropout layer'''
    return {'dropout': {
        'rate': dropout_rate
    }}

# %%
layers = []

# Setup layers
layers.append(dense_layer(12, 'leaky_relu'))
layers.append(batch_norm(0.999))
layers.append(dense_layer(5, 'leaky_relu'))
layers.append(dense_layer(2, 'leaky_relu'))

layers.append(dense_layer(1, 'linear'))

# %%
# We now want the actual neural network properties
# Usually you set this using a YAML file (see configs for some examples) but we'll do this manually for now
build_settings = {
    # Loss function
    'loss': 'mae',
    # Metrics to measure
    'metrics': ['mae', 'mse'],
    # Learning 
    'learning_rate': 1e-2
}

# Settings used when the model is fitting
fit_settings = {
    'batch_size': 8,  # smaller batches often help stability
    'epochs': 200,
    'validation_split': 0.2,
}

# %%
# Now we can make the model
ml_model = ml_factory.make_interface('TensorFlow', 'sequential', Layers=layers, FitSettings=fit_settings, BuildSettings=build_settings)

# Let's use 20% of the data for testing
ml_model.set_training_test_set(0.5)

# %%
# Now we need to train our network
ml_model.train_model()
# Out:
# Epoch 1/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 1.7478 - mae: 0.7880 - mse: 1.0187 - val_loss: 0.7911 - val_mae: 0.7911 - val_mse: 1.0371 - learning_rate: 0.0100
# Epoch 2/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss: 0.7852 - mae: 0.7848 - mse: 1.0086 - val_loss: 0.7894 - val_mae: 0.7894 - val_mse: 1.0215 - learning_rate: 0.0100
# Epoch 3/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - loss: 0.7838 - mae: 0.7836 - mse: 1.0074 - val_loss: 0.7902 - val_mae: 0.7901 - val_mse: 1.0118 - learning_rate: 0.0100
# Epoch 4/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 0.7803 - mae: 0.7801 - mse: 0.9985 - val_loss: 0.7908 - val_mae: 0.7900 - val_mse: 1.0288 - learning_rate: 0.0100
# Epoch 5/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 34s 7ms/step - loss: 0.7840 - mae: 0.7837 - mse: 1.0070 - val_loss: 0.7897 - val_mae: 0.7895 - val_mse: 1.0148 - learning_rate: 0.0100
# Epoch 6/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - loss: 0.7801 - mae: 0.7798 - mse: 0.9960 - val_loss: 0.7904 - val_mae: 0.7903 - val_mse: 1.0114 - learning_rate: 0.0100
# Epoch 7/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 51s 10ms/step - loss: 0.7856 - mae: 0.7855 - mse: 1.0080 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0202 - learning_rate: 0.0100
# Epoch 8/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 52s 10ms/step - loss: 0.7821 - mae: 0.7820 - mse: 1.0050 - val_loss: 0.7901 - val_mae: 0.7900 - val_mse: 1.0121 - learning_rate: 0.0100
# Epoch 9/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 56s 11ms/step - loss: 0.7847 - mae: 0.7845 - mse: 1.0035 - val_loss: 0.7902 - val_mae: 0.7902 - val_mse: 1.0117 - learning_rate: 0.0100
# Epoch 10/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 53s 11ms/step - loss: 0.7840 - mae: 0.7839 - mse: 1.0009 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0192 - learning_rate: 0.0100
# Epoch 11/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 52s 10ms/step - loss: 0.7867 - mae: 0.7863 - mse: 1.0180 - val_loss: 0.7894 - val_mae: 0.7893 - val_mse: 1.0191 - learning_rate: 0.0100
# Epoch 12/200
# 4979/4980 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7802 - mae: 0.7802 - mse: 0.9949
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 57s 11ms/step - loss: 0.7802 - mae: 0.7802 - mse: 0.9949 - val_loss: 0.7899 - val_mae: 0.7898 - val_mse: 1.0276 - learning_rate: 0.0100
# Epoch 13/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 55s 11ms/step - loss: 0.7832 - mae: 0.7832 - mse: 1.0068 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0178 - learning_rate: 1.0000e-03
# Epoch 14/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 42s 8ms/step - loss: 0.7853 - mae: 0.7853 - mse: 1.0057 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0192 - learning_rate: 1.0000e-03
# Epoch 15/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - loss: 0.7893 - mae: 0.7893 - mse: 1.0239 - val_loss: 0.7895 - val_mae: 0.7895 - val_mse: 1.0148 - learning_rate: 1.0000e-03
# Epoch 16/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 0.7846 - mae: 0.7846 - mse: 1.0103 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0192 - learning_rate: 1.0000e-03
# Epoch 17/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 0.7831 - mae: 0.7831 - mse: 1.0059 - val_loss: 0.7901 - val_mae: 0.7900 - val_mse: 1.0121 - learning_rate: 1.0000e-03
# Epoch 18/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss: 0.7800 - mae: 0.7800 - mse: 0.9984 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0180 - learning_rate: 1.0000e-03
# Epoch 19/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 41s 8ms/step - loss: 0.7865 - mae: 0.7865 - mse: 1.0115 - val_loss: 0.7894 - val_mae: 0.7894 - val_mse: 1.0162 - learning_rate: 1.0000e-03
# Epoch 20/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 45s 9ms/step - loss: 0.7774 - mae: 0.7774 - mse: 0.9927 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0206 - learning_rate: 1.0000e-03
# Epoch 21/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 46s 9ms/step - loss: 0.7857 - mae: 0.7857 - mse: 1.0140 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0175 - learning_rate: 1.0000e-03
# Epoch 22/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - loss: 0.7849 - mae: 0.7849 - mse: 1.0109 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0209 - learning_rate: 1.0000e-03
# Epoch 23/200
# 4975/4980 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7798 - mae: 0.7798 - mse: 0.9988
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - loss: 0.7798 - mae: 0.7798 - mse: 0.9988 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0181 - learning_rate: 1.0000e-03
# Epoch 24/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 0.7814 - mae: 0.7814 - mse: 1.0060 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0175 - learning_rate: 1.0000e-04
# Epoch 25/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss: 0.7801 - mae: 0.7801 - mse: 0.9977 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0176 - learning_rate: 1.0000e-04
# Epoch 26/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss: 0.7795 - mae: 0.7795 - mse: 0.9941 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0169 - learning_rate: 1.0000e-04
# Epoch 27/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 0.7817 - mae: 0.7817 - mse: 0.9997 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0174 - learning_rate: 1.0000e-04
# Epoch 28/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 0.7842 - mae: 0.7842 - mse: 1.0125 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0174 - learning_rate: 1.0000e-04
# Epoch 29/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss: 0.7839 - mae: 0.7839 - mse: 1.0070 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0171 - learning_rate: 1.0000e-04
# Epoch 30/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 0.7835 - mae: 0.7835 - mse: 1.0145 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0174 - learning_rate: 1.0000e-04
# Epoch 31/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.7819 - mae: 0.7819 - mse: 1.0002 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0176 - learning_rate: 1.0000e-04
# Epoch 32/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 0.7882 - mae: 0.7882 - mse: 1.0165 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0178 - learning_rate: 1.0000e-04
# Epoch 33/200
# 4970/4980 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7857 - mae: 0.7857 - mse: 1.0076
# Epoch 33: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - loss: 0.7857 - mae: 0.7857 - mse: 1.0076 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0177 - learning_rate: 1.0000e-04
# Epoch 34/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 22s 4ms/step - loss: 0.7829 - mae: 0.7829 - mse: 1.0120 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0177 - learning_rate: 1.0000e-05
# Epoch 35/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss: 0.7840 - mae: 0.7840 - mse: 1.0070 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0177 - learning_rate: 1.0000e-05
# Epoch 36/200
# 4980/4980 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss: 0.7862 - mae: 0.7862 - mse: 1.0100 - val_loss: 0.7893 - val_mae: 0.7893 - val_mse: 1.0176 - learning_rate: 1.0000e-05

# %%
# Now we need to test
ml_model.test_model()
# Out:
# Training Results!
# Mean Absolute Error : 0.7845103843188149
# Line of best fit : y=1.386725742291039e-15x + -1.3672729425311394e-16
# Saving QQ to train_qq_plot.pdf
# mean: 0.09859721362590791, std dev: 0.9999999999999999
# =====
# Testing Results!
# Mean Absolute Error : 0.7890706801429641
# Line of best fit : y=-0.010476199410860395x + 0.0010329240712993806
# Saving QQ to .pdf
# mean: 0.1006630617685073, std dev: 1.0063559086445055
# =====

# %%
# Now we can save it
ml_model.save_model(f"{model_output}.keras")


# We need to save the scaling information
ml_model.save_scaler(str(model_output.parent.joinpath(Path("my_scaler.pkl"))))
print("Model saved to: ", model_output)
print("Scaler saved to: ", model_output.parent.joinpath(Path("my_scaler.pkl")))
# Out:
# Model saved to:  ..\models\my_model
# Scaler saved to:  ..\models\my_scaler.pkl

# %%
ml_model._model.summary()

print(ml_model._model.weights)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 12)             │           264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 12)             │            48 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │            65 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1
#  -0.15324554 -0.00975768  0.00242522 -0.17144382  0.02914626  0.18267936]>, <Variable path=sequential/batch_normalization/moving_mean, shape=(12,), dtype=float32, value=[-0.03472574  0.0179254   0.0433499  -0.02090753 -0.00278619 -0.01493069
#   0.00983256 -0.01496236  0.08494888  0.2141697   0.05566959  0.01780805]>, <Variable path=sequential/batch_normalization/moving_variance, shape=(12,), dtype=float32, value=[3.8395875e-14 9.7676023e-13 9.6192477e-13 4.1617405e-14 3.9737782e-14
#  4.0087081e-14 9.5114346e-13 3.9416712e-14 9.4071268e-13 9.7660985e-13
#  9.4202955e-13 1.0013907e-12]>, <Variable path=sequential/dense_1/kernel, shape=(12, 5), dtype=float32, value=[[-1.2031216e-11  4.0239947e-13  3.4197834e-07  3.8029128e-08
#    2.6855589e-09]
#  [-4.3022000e-10 -1.8793336e-09  4.5333120e-08 -1.5398096e-11
#   -7.1226673e-09]
#  [-1.4039176e-11 -5.1337178e-11  2.1162130e-09  9.4452106e-11
#    1.5974572e-11]
#  [ 5.6387535e-09  1.3113199e-11  4.4892334e-07  8.0464330e-11
#    9.2178804e-13]
#  [ 4.3546571e-08 -3.1499345e-11  8.7312323e-08  1.9343888e-12
#   -7.6438869e-11]
#  [ 3.0183531e-09 -6.4649930e-12  6.6908452e-09 -4.3260115e-09
#   -4.9454069e-12]
#  [-5.2612947e-10  3.2856784e-12  3.2635462e-08 -3.4978305e-12
#   -1.2608195e-10]
#  [-1.3233173e-10 -3.6206302e-11 -3.0989852e-08 -1.8580627e-07
#    3.9113729e-07]
#  [ 2.5443123e-09  4.7743787e-10 -5.8743649e-11 -3.8043332e-08
#    2.7654323e-09]
#  [ 1.0309401e-06 -1.1316352e-08  4.2507672e-08 -7.5431120e-11
#   -5.0798454e-09]
#  [-1.0337863e-12  1.7414013e-12 -4.6048804e-10  3.3031064e-08
#    8.4679663e-10]
#  [ 2.5382501e-09  1.7541710e-12  2.7597391e-08 -3.2036769e-11
#    5.6097326e-07]]>, <Variable path=sequential/dense_1/bias, shape=(5,), dtype=float32, value=[-0.28803122 -0.31512174  0.11111783  0.37679073 -0.26250294]>, <Variable path=sequential/dense_2/kernel, shape=(5, 2), dtype=float32, value=[[-8.2815961e-07 -8.2805354e-07]
#  [-3.6455572e-07 -3.6421079e-07]
#  [ 2.2372449e-06  2.2368879e-06]
#  [-1.1729257e-06 -1.1730165e-06]
#  [-9.9372846e-07 -9.9368117e-07]]>, <Variable path=sequential/dense_2/bias, shape=(2,), dtype=float32, value=[-0.19230905 -0.19249927]>, <Variable path=sequential/dense_3/kernel, shape=(2, 1), dtype=float32, value=[[-0.00019078]
#  [-0.00019079]]>, <Variable path=sequential/dense_3/bias, shape=(1,), dtype=float32, value=[-0.0986119]>]
